# %%
from datetime import datetime, timedelta
import uo_pyfetch

import calendar
from datetime import datetime, timezone

import numpy as np
import pandas as pd

# %%
df = pd.read_csv("..\\csv_extraction\\sensor_data_2024_01.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                  Sensor_Name      Variable  Value  \
# 0           0  PER_NE_CAJT_NCA189_BR3_SJB2     Plates In    3.0
# 1           1  PER_NE_CAJT_NCA189_SJB2_BR3     Plates In    6.0
# 2           2  PER_NE_CAJT_NCA189_BR3_SJB2  Journey Time  107.0
# 3           3  PER_NE_CAJT_NCA189_SJB2_BR3    Plates Out    3.0
# 4           4  PER_NE_CAJT_NCA189_BR3_SJB2    Plates Out    8.0
#
#              Timestamp  Flagged  \
# 0  2024-01-01 00:03:00    False
# 1  2024-01-01 00:03:00    False
# 2  2024-01-01 00:03:00    False
# 3  2024-01-01 00:03:00    False
# 4  2024-01-01 00:03:00    False
#
#                                         Location_WKT  \
# 0  LINESTRING(-1.63616906955424 54.9817218898528,...
# 1  LINESTRING(-1.62151252520077 54.9734188344729,...
# 2  LINESTRING(-1.63616906955424 54.9817218898528,...
# 3  LINESTRING(-1.62151252520077 54.9734188344729,...
# 4  LINESTRING(-1.63616906955424 54.9817218898528,...
#
# ...

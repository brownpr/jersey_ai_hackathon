# %%
from datetime import datetime, timedelta
import uo_pyfetch

# %%
def get_variable_data(dt1: datetime, dt2: datetime, bbox):
    sensor_data_df = uo_pyfetch.get_sensor_data(
        start=dt1,
        end=dt2,
        variables=None,  # or list of vars if you want to filter
        bbox=bbox,
        limit=1000
    )
    return sensor_data_df

# %%
dt2 = datetime.now()
dt1 = datetime(2025, 10, 31, 23, 59)

bbox = [-1.652756, 54.973377, -1.620483, 54.983721]

df = get_variable_data(dt1, dt2, bbox)

# %%
df
# Out:
#                      Sensor_Name         Variable  Value            Timestamp  \
# 0    PER_NE_CAJT_NCA189_BR3_SJB2        Plates In   16.0  2025-10-31 23:59:00
# 1    PER_NE_CAJT_NCA189_BR3_SJB2       Plates Out   15.0  2025-10-31 23:59:00
# 2    PER_NE_CAJT_NCA189_BR3_SJB2     Journey Time  166.0  2025-10-31 23:59:00
# 3    PER_NE_CAJT_NCA189_BR3_SJB2  Plates Matching    3.0  2025-10-31 23:59:00
# 4    PER_NE_CAJT_NCA189_SJB2_BR3  Plates Matching    3.0  2025-10-31 23:59:00
# ..                           ...              ...    ...                  ...
# 995  PER_NE_CAJT_NCA189_BR3_SJB2       Plates Out    1.0  2025-11-01 05:39:00
# 996  PER_NE_CAJT_NCA189_BR3_SJB2     Journey Time   99.0  2025-11-01 05:39:00
# 997  PER_NE_CAJT_NCA189_BR3_SJB2     Journey Time   99.0  2025-11-01 05:43:00
# 998  PER_NE_CAJT_NCA189_SJB2_BR3     Journey Time  102.0  2025-11-01 05:43:00
# 999  PER_NE_CAJT_NCA189_SJB2_BR3       Plates Out   12.0  2025-11-01 05:43:00
#
#      Flagged                                       Location_WKT  \
# 0      False  LINESTRING(-1.63616906955424 54.9817218898528,...
# 1      False  LINESTRING(-1.63616906955424 54.9817218898528,...
# 2      False  LINESTRING(-1.63616906955424 54.9817218898528,...
# 3      False  LINESTRING(-1.63616906955424 54.9817218898528,...
# 4      False  LINESTRING(-1.62151252520077 54.9734188344729,...
# ..       ...                                                ...
# 995    False  LINESTRING(-1.63616906955424 54.9817218898528,...
# 996    False  LINESTRING(-1.63616906955424 54.9817218898528,...
# 997    False  LINESTRING(-1.63616906955424 54.9817218898528,...
# 998    False  LINESTRING(-1.62151252520077 54.9734188344729,...
# 999    False  LINESTRING(-1.62151252520077 54.9734188344729,...
#
#      Sensor_Centroid_Longitude  Ground_Height_Above_Sea_Level  \
# 0                    -1.628878                      79.949997
# 1                    -1.628878                      79.949997
# 2                    -1.628878                      79.949997
# 3                    -1.628878                      79.949997
# 4                    -1.628609                      75.330002
# ..                         ...                            ...
# 995                  -1.628878                      79.949997
# 996                  -1.628878                      79.949997
# 997                  -1.628878                      79.949997
# 998                  -1.628609                      75.330002
# 999                  -1.628609                      75.330002
#
#      Sensor_Centroid_Latitude  Sensor_Height_Above_Ground         Broker_Name  \
# 0                   54.977755                         2.0  NE Travel Data API
# 1                   54.977755                         2.0  NE Travel Data API
# 2                   54.977755                         2.0  NE Travel Data API
# 3                   54.977755                         2.0  NE Travel Data API
# 4                   54.977332                         2.0  NE Travel Data API
# ..                        ...                         ...                 ...
# 995                 54.977755                         2.0  NE Travel Data API
# 996                 54.977755                         2.0  NE Travel Data API
# 997                 54.977755                         2.0  NE Travel Data API
# 998                 54.977332                         2.0  NE Travel Data API
# 999                 54.977332                         2.0  NE Travel Data API
#
#      Raw_ID
# 0     73162
# 1     73162
# 2     73162
# 3     73162
# 4     73173
# ..      ...
# 995   73162
# 996   73162
# 997   73162
# 998   73173
# 999   73173
#
# [1000 rows x 12 columns]
